# %% [markdown]
# ## 主程式 - (1)

# %%
import pandas as pd
import re, time, requests
from selenium import webdriver
from bs4 import BeautifulSoup as bs

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.193 Safari/537.36'}

my_paras = {'ro':'1',             # 限定金額和工作，若不限定則輸入 0 
            'keyword':'韓文',      # 想要查詢的工作關鍵字 
            'area':'6001001000',  # 限定在台北市的工作 (新北 6001002000)
            'isnew': '30',        # 只要最近一個月有更新的職缺
            'mode': '1'}          # 清單的瀏覽模式


r = requests.get('https://www.104.com.tw/jobs/search/?', my_paras, headers=headers)
print("Target url is: ",r.url)
url = r.url
driver = webdriver.Chrome()
driver.get(url)

# 滑到下方以載入更多資料，送入的是 Java語法
for i in range(20):
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.6)
    
    
# 自動加載只會加載15次，超過之後必須點選「手動載入」按鈕才會繼續加載
k = 1
while k != 0:
    try :
        driver.find_element_by_class_name("js-more-page",)[-1].click()
        print(f'Click 手動載入，載入第{15+k}頁')
        k += 1
        time.sleep(1)
    except:
        k = 0
        print('no more job')
        

soup = bs(driver.page_source, 'lxml')
jobs_list = soup.findAll('a', {'class': 'js-job-link'})
print(f'共有{len(jobs_list)}筆資料')
# Out:
# Target url is:  https://www.104.com.tw/jobs/search/?ro=1&keyword=%E9%9F%93%E6%96%87&area=6001001000&isnew=30&mode=1
# no more job
# 共有120筆資料

# %% [markdown]
# ## 主程式 - (2)

# %%
# 專於用來處理「職務類別」這個複選
def bind(cate):
    k = []
    for i in cate:
        if len(i.text) > 0:
            k.append(i.text)
    return str(k)

JobList = pd.DataFrame()


i = 0
while i < len(jobs_list):
    print('正在處理第' + str(i) + '筆，共 ' + str(len(jobs_list)) + ' 筆資料')
    content = jobs_list[i]
    # Try: 爬太快會遭到系統阻擋導失敗。
    try:
        headers2 = {
            "Referer": "https://www.104.com.tw/job/6vrlf",
        }

        resp2 = requests.get('https://' + content.attrs['href'].strip('//'), headers=headers2)
        driver.get(resp2.url)
        html_rendered = driver.page_source
        soup2 = bs(html_rendered, 'lxml')
        
        # 有些沒有公司福利欄位
        try:
            公司福利 = soup2.select('.benefits-description div p')[0].text
        except:
            print('本職缺沒有公司福利')
            公司福利 = '沒有'
        
        df = pd.DataFrame(
            data = [{
                '公司名稱':soup2.select('div.job-header__title > div > a')[0].text,
                '工作職稱':content.text,
                '工作內容':soup2.select('div.container div.row .job-description p')[0].text,
                '職務類別':bind(soup2.select('.identity-type div div u')),
                '工作待遇':soup2.select('div.container div.row .job-description p')[1].text,
                '工作性質':soup2.select('div.container div.row .job-description p')[2].text,
                '上班地點':soup2.select('div.container div.row .job-description p')[3].text,
                '管理責任':soup2.select('div.container div.row .job-description p')[4].text,
                '出差外派':soup2.select('div.container div.row .job-description p')[5].text,
                '上班時段':soup2.select('div.container div.row .job-description p')[6].text,
                '休假制度':soup2.select('div.container div.row .job-description p')[7].text,
                '可上班日':soup2.select('div.container div.row .job-description p')[8].text,
                '需求人數':soup2.select('div.container div.row .job-description p')[9].text,
                '接受身份':bind(soup2.select('.job-requirement-table .identity-type')),
                '工作經歷':soup2.select('.job-requirement-table .row div p')[0].text,
                '學歷要求':soup2.select('.job-requirement-table .row div p')[1].text,
                '科系要求':soup2.select('.job-requirement-table .row div p')[2].text,
                '語文或工具':bind(soup2.select('.job-requirement-table .row div p')[3:]),
                '其他條件':soup2.select('.job-requirement .row div p')[-1].text,
                '公司福利':公司福利,
                '連結路徑':'https://' + content.attrs['href'].strip('//')}],
            columns = ['公司名稱','工作職稱','工作內容','職務類別','工作待遇','工作性質','上班地點','管理責任','出差外派',
                       '上班時段','休假制度','可上班日','需求人數','接受身份','工作經歷','學歷要求','科系要求','語文或工具',
                       '其他條件','公司福利','連結路徑'])
        JobList = JobList.append(df, ignore_index=True)
        i += 1
        print("Success and Crawl Next 目前正在爬第" + str(i) + "個職缺資訊")
        time.sleep(0.5) # 執行完休息0.5秒，避免造成對方主機負擔
    except:
        print("Fail and Try Again!")


print('... 輸出結果至 excel ... ')
JobList.to_excel('JobList2.xlsx', encoding='cp950')
# Out:
# 正在處理第0筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第1個職缺資訊
# 正在處理第1筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第2個職缺資訊
# 正在處理第2筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第2筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第3個職缺資訊
# 正在處理第3筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第4個職缺資訊
# 正在處理第4筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第5個職缺資訊
# 正在處理第5筆，共 120 筆資料
# 本職缺沒有公司福利
# Success and Crawl Next 目前正在爬第6個職缺資訊
# 正在處理第6筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第7個職缺資訊
# 正在處理第7筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第8個職缺資訊
# 正在處理第8筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第9個職缺資訊
# 正在處理第9筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第10個職缺資訊
# 正在處理第10筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第11個職缺資訊
# 正在處理第11筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第12個職缺資訊
# 正在處理第12筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第13個職缺資訊
# 正在處理第13筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第14個職缺資訊
# 正在處理第14筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第15個職缺資訊
# 正在處理第15筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第15筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第16個職缺資訊
# 正在處理第16筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第16筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第17個職缺資訊
# 正在處理第17筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第18個職缺資訊
# 正在處理第18筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第19個職缺資訊
# 正在處理第19筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第20個職缺資訊
# 正在處理第20筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第21個職缺資訊
# 正在處理第21筆，共 120 筆資料
# 本職缺沒有公司福利
# Success and Crawl Next 目前正在爬第22個職缺資訊
# 正在處理第22筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第23個職缺資訊
# 正在處理第23筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第24個職缺資訊
# 正在處理第24筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第25個職缺資訊
# 正在處理第25筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第26個職缺資訊
# 正在處理第26筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第27個職缺資訊
# 正在處理第27筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第28個職缺資訊
# 正在處理第28筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第29個職缺資訊
# 正在處理第29筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第29筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第30個職缺資訊
# 正在處理第30筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第31個職缺資訊
# 正在處理第31筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第32個職缺資訊
# 正在處理第32筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第33個職缺資訊
# 正在處理第33筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第34個職缺資訊
# 正在處理第34筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第35個職缺資訊
# 正在處理第35筆，共 120 筆資料
# Fail and Try Again!
# 正在處理第35筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第36個職缺資訊
# 正在處理第36筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第37個職缺資訊
# 正在處理第37筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第38個職缺資訊
# 正在處理第38筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第39個職缺資訊
# 正在處理第39筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第40個職缺資訊
# 正在處理第40筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第41個職缺資訊
# 正在處理第41筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第42個職缺資訊
# 正在處理第42筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第43個職缺資訊
# 正在處理第43筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第44個職缺資訊
# 正在處理第44筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第45個職缺資訊
# 正在處理第45筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第46個職缺資訊
# 正在處理第46筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第47個職缺資訊
# 正在處理第47筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第47筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第48個職缺資訊
# 正在處理第48筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第49個職缺資訊
# 正在處理第49筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第50個職缺資訊
# 正在處理第50筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第51個職缺資訊
# 正在處理第51筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第52個職缺資訊
# 正在處理第52筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第52筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第53個職缺資訊
# 正在處理第53筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第54個職缺資訊
# 正在處理第54筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第55個職缺資訊
# 正在處理第55筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第56個職缺資訊
# 正在處理第56筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第57個職缺資訊
# 正在處理第57筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第58個職缺資訊
# 正在處理第58筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第59個職缺資訊
# 正在處理第59筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第60個職缺資訊
# 正在處理第60筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第61個職缺資訊
# 正在處理第61筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第61筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第62個職缺資訊
# 正在處理第62筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第63個職缺資訊
# 正在處理第63筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第64個職缺資訊
# 正在處理第64筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第65個職缺資訊
# 正在處理第65筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第66個職缺資訊
# 正在處理第66筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第67個職缺資訊
# 正在處理第67筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第68個職缺資訊
# 正在處理第68筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第69個職缺資訊
# 正在處理第69筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第70個職缺資訊
# 正在處理第70筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第71個職缺資訊
# 正在處理第71筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第72個職缺資訊
# 正在處理第72筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第73個職缺資訊
# 正在處理第73筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第74個職缺資訊
# 正在處理第74筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第75個職缺資訊
# 正在處理第75筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第76個職缺資訊
# 正在處理第76筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第77個職缺資訊
# 正在處理第77筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第78個職缺資訊
# 正在處理第78筆，共 120 筆資料
# 本職缺沒有公司福利
# Success and Crawl Next 目前正在爬第79個職缺資訊
# 正在處理第79筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第80個職缺資訊
# 正在處理第80筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第80筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第81個職缺資訊
# 正在處理第81筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第82個職缺資訊
# 正在處理第82筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第83個職缺資訊
# 正在處理第83筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第84個職缺資訊
# 正在處理第84筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第84筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第85個職缺資訊
# 正在處理第85筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第86個職缺資訊
# 正在處理第86筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第87個職缺資訊
# 正在處理第87筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第88個職缺資訊
# 正在處理第88筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第89個職缺資訊
# 正在處理第89筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第89筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第90個職缺資訊
# 正在處理第90筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第91個職缺資訊
# 正在處理第91筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第92個職缺資訊
# 正在處理第92筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第93個職缺資訊
# 正在處理第93筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第94個職缺資訊
# 正在處理第94筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第95個職缺資訊
# 正在處理第95筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第96個職缺資訊
# 正在處理第96筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第97個職缺資訊
# 正在處理第97筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第98個職缺資訊
# 正在處理第98筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第99個職缺資訊
# 正在處理第99筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第100個職缺資訊
# 正在處理第100筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第101個職缺資訊
# 正在處理第101筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第101筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第102個職缺資訊
# 正在處理第102筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第103個職缺資訊
# 正在處理第103筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第104個職缺資訊
# 正在處理第104筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第105個職缺資訊
# 正在處理第105筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第106個職缺資訊
# 正在處理第106筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第107個職缺資訊
# 正在處理第107筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第108個職缺資訊
# 正在處理第108筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第109個職缺資訊
# 正在處理第109筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第109筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第110個職缺資訊
# 正在處理第110筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第111個職缺資訊
# 正在處理第111筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第112個職缺資訊
# 正在處理第112筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第113個職缺資訊
# 正在處理第113筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第114個職缺資訊
# 正在處理第114筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第115個職缺資訊
# 正在處理第115筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第116個職缺資訊
# 正在處理第116筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第116筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第117個職缺資訊
# 正在處理第117筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第118個職缺資訊
# 正在處理第118筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第119個職缺資訊
# 正在處理第119筆，共 120 筆資料
# 本職缺沒有公司福利
# Fail and Try Again!
# 正在處理第119筆，共 120 筆資料
# Success and Crawl Next 目前正在爬第120個職缺資訊
# ... 輸出結果至 excel ...
